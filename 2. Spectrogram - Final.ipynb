# %% [markdown]
# # Spectrogram: Visualizing Sound

# %% [markdown]
# A spectrogram shows audio data as spectral intensities over time. On the y axis you can see frequencies, which are plotted over time on the x axis. The colours indicate power or loudness of the sound signals recorded. In the spectrogram below, the yellow and bright green time periods had the loudest sounds

# %% [markdown]
# <img src="/Ice Draft/ICLISTENHF1951_20231219T013239.000Z-spect.png" width="" align="" />

# %% [markdown]
# In this exercise we are going to request an audio spectrogram.

# %% [markdown]
# ## Import libraries

# %%
#import all libraries needed to run your codes
from onc import ONC
import os

onc = ONC('ENTER_YOUR_TOKEN_HERE')                # Enter your token here

# %% [markdown]
# ## Request a spectrogram file

# %% [markdown]
# This code uses the archiveFiles service to request a spectrogram in the png format from 1 July 2019.

# %%
# Download the arcived audio spectrogram file from Cambridge Bay for July 1, 2019; The file will be downloaded to a
# directory in the left side panel named: output

response = onc.downloadArchivefile('ICLISTENHF1266_20190701T162319.885Z-spect.png', overwrite=True)
# Out:
# {'url': 'https://data.oceannetworks.ca/api/archivefiles?token=20e46e94-e914-48b4-add6-fe8abe12b88d&method=getFile&filename=ICLISTENHF1266_20190701T162319.885Z-spect.png',
#  'status': 'completed',
#  'size': 91321,
#  'downloadTime': 0.055,
#  'file': 'ICLISTENHF1266_20190701T162319.885Z-spect.png'}

# %% [markdown]
# Now look in your Files at left for the file ICLISTENHF1266_20190701T161819.885Z-spect.png. Open this file and look at it. There was some noise just before 16:26 in the recording. What was that noise?

# %% [markdown]
# <img src="/Spectrogram Folder/cambridge_bay_mystery_sound.png" width="" align="" />

# %% [markdown]
# In the next Notebook we will listen to that sound.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=75d72e45-1509-4fbb-beb6-c2919c7487ef' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
